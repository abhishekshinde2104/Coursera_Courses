# %%
import pandas as pd
import numpy as np

# %%
energy = pd.read_excel('Energy Indicators.xls', skiprows=17,skipfooter= 38)
energy
# Out:
#      Unnamed: 0                 Unnamed: 1                 Unnamed: 2  \
# 0           NaN                Afghanistan                Afghanistan
# 1           NaN                    Albania                    Albania
# 2           NaN                    Algeria                    Algeria
# 3           NaN             American Samoa             American Samoa
# 4           NaN                    Andorra                    Andorra
# ..          ...                        ...                        ...
# 222         NaN                   Viet Nam                   Viet Nam
# 223         NaN  Wallis and Futuna Islands  Wallis and Futuna Islands
# 224         NaN                      Yemen                      Yemen
# 225         NaN                     Zambia                     Zambia
# 226         NaN                   Zimbabwe                   Zimbabwe
#
#     Petajoules Gigajoules           %
# 0          321         10   78.669280
# 1          102         35  100.000000
# 2         1959         51    0.551010
# 3          ...        ...    0.641026
# 4            9        121   88.695650
# ..         ...        ...         ...
# 222       2554         28   45.321520
# 223          0         26    0.000000
# 224        344         13    0.000000
# 225        400         26   99.714670
# 226        480         32   52.536120
#
# [227 rows x 6 columns]

# %%
energy.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Petajoules', 'Gigajoules',
#        '%'],
#       dtype='object')

# %%
energy=energy.iloc[:,2:]
energy
#Another way to keep limited columns is 
#energy = energy[['Unnamed: 1','Petajoules','Gigajoules','%']]
# Out:
#                     Unnamed: 2 Petajoules Gigajoules           %
# 0                  Afghanistan        321         10   78.669280
# 1                      Albania        102         35  100.000000
# 2                      Algeria       1959         51    0.551010
# 3               American Samoa        ...        ...    0.641026
# 4                      Andorra          9        121   88.695650
# ..                         ...        ...        ...         ...
# 222                   Viet Nam       2554         28   45.321520
# 223  Wallis and Futuna Islands          0         26    0.000000
# 224                      Yemen        344         13    0.000000
# 225                     Zambia        400         26   99.714670
# 226                   Zimbabwe        480         32   52.536120
#
# [227 rows x 4 columns]

# %%
energy.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
energy
# Out:
#                        Country Energy Supply Energy Supply per Capita  \
# 0                  Afghanistan           321                       10
# 1                      Albania           102                       35
# 2                      Algeria          1959                       51
# 3               American Samoa           ...                      ...
# 4                      Andorra             9                      121
# ..                         ...           ...                      ...
# 222                   Viet Nam          2554                       28
# 223  Wallis and Futuna Islands             0                       26
# 224                      Yemen           344                       13
# 225                     Zambia           400                       26
# 226                   Zimbabwe           480                       32
#
#      % Renewable
# 0      78.669280
# 1     100.000000
# 2       0.551010
# 3       0.641026
# 4      88.695650
# ..           ...
# 222    45.321520
# 223     0.000000
# 224     0.000000
# 225    99.714670
# 226    52.536120
#
# [227 rows x 4 columns]

# %%
energy['Energy Supply']=energy['Energy Supply']*1000000

# %%
energy
# Out:
#                        Country  \
# 0                  Afghanistan
# 1                      Albania
# 2                      Algeria
# 3               American Samoa
# 4                      Andorra
# ..                         ...
# 222                   Viet Nam
# 223  Wallis and Futuna Islands
# 224                      Yemen
# 225                     Zambia
# 226                   Zimbabwe
#
#                                          Energy Supply  \
# 0                                            321000000
# 1                                            102000000
# 2                                           1959000000
# 3    .................................................
# 4                                              9000000
# ..                                                 ...
# 222                                         2554000000
# 223                                                  0
# 224                                          344000000
# 225                                          400000000
# 226                                          480000000
#
#     Energy Supply per Capita  % Renewable
# 0                         10    78.669280
# 1                         35   100.000000
# 2                         51     0.551010
# 3                        ...     0.641026
# 4                        121    88.695650
# ..                       ...          ...
# 222                       28    45.321520
# 223                       26     0.000000
# 224                       13     0.000000
# 225                       26    99.714670
# 226                       32    52.536120
#
# [227 rows x 4 columns]

# %%
energy['Country'][2]
# Out:
# 'Algeria'

# %%
i=energy[energy['Country']=='Algeria'].index

# %%
print(i)
# Out:
# Int64Index([2], dtype='int64')

# %%
#this gives the particular index of any country in the dataset
j=energy[energy['Country']=='Algeria'].index.values
print(j)
# Out:
# [2]

# %%
j=energy[energy['Country']=='Switzerland17'].index.values
print(j)
# Out:
# [197]

# %%
energy[['Country']]
# Out:
#                        Country
# 0                  Afghanistan
# 1                      Albania
# 2                      Algeria
# 3               American Samoa
# 4                      Andorra
# ..                         ...
# 222                   Viet Nam
# 223  Wallis and Futuna Islands
# 224                      Yemen
# 225                     Zambia
# 226                   Zimbabwe
#
# [227 rows x 1 columns]

# %%
energy[['Country']]=energy[['Country']].replace?
# Out:
# Object `replace` not found.

# %%
energy[['Country']]=energy[['Country']].replace

# %%
energy['Country']=energy['Country'].replace('...',np.NaN)

# %%
energy
# Out:
#                        Country  \
# 0                  Afghanistan
# 1                      Albania
# 2                      Algeria
# 3               American Samoa
# 4                      Andorra
# ..                         ...
# 222                   Viet Nam
# 223  Wallis and Futuna Islands
# 224                      Yemen
# 225                     Zambia
# 226                   Zimbabwe
#
#                                          Energy Supply  \
# 0                                            321000000
# 1                                            102000000
# 2                                           1959000000
# 3    .................................................
# 4                                              9000000
# ..                                                 ...
# 222                                         2554000000
# 223                                                  0
# 224                                          344000000
# 225                                          400000000
# 226                                          480000000
#
#     Energy Supply per Capita  % Renewable
# 0                         10    78.669280
# 1                         35   100.000000
# 2                         51     0.551010
# 3                        ...     0.641026
# 4                        121    88.695650
# ..                       ...          ...
# 222                       28    45.321520
# 223                       26     0.000000
# 224                       13     0.000000
# 225                       26    99.714670
# 226                       32    52.536120
#
# [227 rows x 4 columns]

# %%
energy['Country'] = energy['Country'].str.replace(" \(.*\)","")#kind of a regular expression
energy
# Out:
#                        Country  \
# 0                  Afghanistan
# 1                      Albania
# 2                      Algeria
# 3               American Samoa
# 4                      Andorra
# ..                         ...
# 222                   Viet Nam
# 223  Wallis and Futuna Islands
# 224                      Yemen
# 225                     Zambia
# 226                   Zimbabwe
#
#                                          Energy Supply  \
# 0                                            321000000
# 1                                            102000000
# 2                                           1959000000
# 3    .................................................
# 4                                              9000000
# ..                                                 ...
# 222                                         2554000000
# 223                                                  0
# 224                                          344000000
# 225                                          400000000
# 226                                          480000000
#
#     Energy Supply per Capita  % Renewable
# 0                         10    78.669280
# 1                         35   100.000000
# 2                         51     0.551010
# 3                        ...     0.641026
# 4                        121    88.695650
# ..                       ...          ...
# 222                       28    45.321520
# 223                       26     0.000000
# 224                       13     0.000000
# 225                       26    99.714670
# 226                       32    52.536120
#
# [227 rows x 4 columns]

# %%
energy[energy['Country']=='Bolivia']
# Out:
#     Country Energy Supply Energy Supply per Capita  % Renewable
# 24  Bolivia     336000000                       32     31.47712

# %%
energy['Country'] = energy['Country'].replace({'China, Hong Kong Special Administrative Region':'Hong Kong','United Kingdom of Great Britain and Northern Ireland':'United Kingdom','Republic of Korea':'South Korea','United States of America':'United States','Iran (Islamic Republic of)':'Iran'})
energy
# Out:
#                        Country  \
# 0                  Afghanistan
# 1                      Albania
# 2                      Algeria
# 3               American Samoa
# 4                      Andorra
# ..                         ...
# 222                   Viet Nam
# 223  Wallis and Futuna Islands
# 224                      Yemen
# 225                     Zambia
# 226                   Zimbabwe
#
#                                          Energy Supply  \
# 0                                            321000000
# 1                                            102000000
# 2                                           1959000000
# 3    .................................................
# 4                                              9000000
# ..                                                 ...
# 222                                         2554000000
# 223                                                  0
# 224                                          344000000
# 225                                          400000000
# 226                                          480000000
#
#     Energy Supply per Capita  % Renewable
# 0                         10    78.669280
# 1                         35   100.000000
# 2                         51     0.551010
# 3                        ...     0.641026
# 4                        121    88.695650
# ..                       ...          ...
# 222                       28    45.321520
# 223                       26     0.000000
# 224                       13     0.000000
# 225                       26    99.714670
# 226                       32    52.536120
#
# [227 rows x 4 columns]

# %%
energy[['Country']]=energy[['Country']].apply(pd.to_numeric)
energy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Afghanistan"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-84f4c300059b> in <module>
# ----> 1 energy[['Country']]=energy[['Country']].apply(pd.to_numeric)
#       2 energy
#
# c:\users\abhishek shinde\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6926             kwds=kwds,
#    6927         )
# -> 6928         return op.get_result()
#    6929
#    6930     def applymap(self, func):
#
# c:\users\abhishek shinde\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# c:\users\abhishek shinde\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# c:\users\abhishek shinde\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# c:\users\abhishek shinde\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     149             coerce_numeric = errors not in ("ignore", "raise")
#     150             values = lib.maybe_convert_numeric(
# --> 151                 values, set(), coerce_numeric=coerce_numeric
#     152             )
#     153
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: ('Unable to parse string "Afghanistan" at position 0', 'occurred at index Country')

# %%
energy = pd.read_excel('Energy Indicators.xls', skiprows=17,skipfooter= 38)
energy=energy.iloc[:,2:]
energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
energy[['Energy Supply', 'Energy Supply per Capita', '% Renewable']] =  energy[['Energy Supply', 'Energy Supply per Capita', '% Renewable']].replace('...',np.NaN).apply(pd.to_numeric)
energy['Energy Supply'] = energy['Energy Supply']*1000000
energy['Country'] = energy['Country'].replace({'China, Hong Kong Special Administrative Region':'Hong Kong','United Kingdom of Great Britain and Northern Ireland':'United Kingdom','Republic of Korea':'South Korea','United States of America':'United States','Iran (Islamic Republic of)':'Iran'})
energy['Country'] = energy['Country'].str.replace(" \(.*\)","")
energy
# Out:
# c:\users\abhishek shinde\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: the 'skip_footer' keyword is deprecated, use 'skipfooter' instead
#   """Entry point for launching an IPython kernel.
#                        Country  Energy Supply  Energy Supply per Capita  \
# 0                  Afghanistan   3.210000e+08                      10.0
# 1                      Albania   1.020000e+08                      35.0
# 2                      Algeria   1.959000e+09                      51.0
# 3               American Samoa            NaN                       NaN
# 4                      Andorra   9.000000e+06                     121.0
# ..                         ...            ...                       ...
# 222                   Viet Nam   2.554000e+09                      28.0
# 223  Wallis and Futuna Islands   0.000000e+00                      26.0
# 224                      Yemen   3.440000e+08                      13.0
# 225                     Zambia   4.000000e+08                      26.0
# 226                   Zimbabwe   4.800000e+08                      32.0
#
#      % Renewable
# 0      78.669280
# 1     100.000000
# 2       0.551010
# 3       0.641026
# 4      88.695650
# ..           ...
# 222    45.321520
# 223     0.000000
# 224     0.000000
# 225    99.714670
# 226    52.536120
#
# [227 rows x 4 columns]

# %%
GDP = pd.read_csv('world_bank.csv',skiprows=4)
GDP['Country Name'] = GDP['Country Name'].replace('Korea, Rep.','South Korea')
GDP['Country Name'] = GDP['Country Name'].replace('Iran, Islamic Rep.','Iran')
GDP['Country Name'] = GDP['Country Name'].replace('Hong Kong SAR, China','Hong Kong')

# %%
GDP
# Out:
#          Country Name Country Code                            Indicator Name  \
# 0               Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1             Andorra          AND  GDP at market prices (constant 2010 US$)
# 2         Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3              Angola          AGO  GDP at market prices (constant 2010 US$)
# 4             Albania          ALB  GDP at market prices (constant 2010 US$)
# ..                ...          ...                                       ...
# 259       Yemen, Rep.          YEM  GDP at market prices (constant 2010 US$)
# 260      South Africa          ZAF  GDP at market prices (constant 2010 US$)
# 261  Congo, Dem. Rep.          COD  GDP at market prices (constant 2010 US$)
# 262            Zambia          ZMB  GDP at market prices (constant 2010 US$)
# 263          Zimbabwe          ZWE  GDP at market prices (constant 2010 US$)
#
#      Indicator Code          1960          1961          1962          1963  \
# 0    NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 1    NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 2    NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 3    NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 4    NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# ..              ...           ...           ...           ...           ...
# 259  NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 260  NY.GDP.MKTP.KD  7.707081e+10  8.003449e+10  8.497844e+10  9.124438e+10
# 261  NY.GDP.MKTP.KD  1.508024e+10  1.344383e+10  1.629401e+10  1.714358e+10
# 262  NY.GDP.MKTP.KD  4.592975e+09  4.655503e+09  4.539542e+09  4.688093e+09
# 263  NY.GDP.MKTP.KD  3.338344e+09  3.549199e+09  3.600111e+09  3.824915e+09
#
#              1964          1965  ...          2006          2007  \
# 0             NaN           NaN  ...           NaN           NaN
# 1             NaN           NaN  ...  4.018196e+09  4.021331e+09
# 2             NaN           NaN  ...  1.030523e+10  1.172119e+10
# 3             NaN           NaN  ...  5.581103e+10  6.842044e+10
# 4             NaN           NaN  ...  9.771760e+09  1.034829e+10
# ..            ...           ...  ...           ...           ...
# 259           NaN           NaN  ...  2.672565e+10  2.761787e+10
# 260  9.848904e+10  1.072507e+11  ...  3.402852e+11  3.585261e+11
# 261  1.672524e+10  1.689205e+10  ...  1.650894e+10  1.754232e+10
# 262  5.260699e+09  6.136472e+09  ...  1.440569e+10  1.560892e+10
# 263  3.782605e+09  3.968352e+09  ...  1.006276e+10  9.695130e+09
#
#              2008          2009          2010          2011          2012  \
# 0             NaN           NaN  2.467704e+09           NaN           NaN
# 1    3.675728e+09  3.535389e+09  3.346317e+09  3.185605e+09  3.129538e+09
# 2    1.214448e+10  1.469733e+10  1.593680e+10  1.691113e+10  1.935220e+10
# 3    7.787420e+10  7.975320e+10  8.247091e+10  8.570262e+10  9.012096e+10
# 4    1.112752e+10  1.150029e+10  1.192695e+10  1.223109e+10  1.240477e+10
# ..            ...           ...           ...           ...           ...
# 259  2.872656e+10  2.991436e+10  3.090675e+10  2.624342e+10  2.689160e+10
# 260  3.699668e+11  3.642764e+11  3.753494e+11  3.874074e+11  3.960071e+11
# 261  1.863448e+10  1.916651e+10  2.052329e+10  2.193213e+10  2.350200e+10
# 262  1.682234e+10  1.837342e+10  2.026555e+10  2.140358e+10  2.302438e+10
# 263  7.982103e+09  8.459783e+09  9.422161e+09  1.054391e+10  1.165789e+10
#
#              2013          2014          2015
# 0             NaN           NaN           NaN
# 1    3.127550e+09           NaN           NaN
# 2    1.973134e+10  1.999032e+10  2.029415e+10
# 3    9.626143e+10  1.008863e+11  1.039106e+11
# 4    1.254247e+10  1.279331e+10  1.312082e+10
# ..            ...           ...           ...
# 259  2.800914e+10           NaN           NaN
# 260  4.047682e+11  4.110369e+11  4.163117e+11
# 261  2.550050e+10  2.778776e+10  2.970961e+10
# 262  2.420595e+10  2.542227e+10  2.624127e+10
# 263  1.218064e+10  1.264939e+10  1.278517e+10
#
# [264 rows x 60 columns]

# %%
columns = ['Country Name','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']
GDP = GDP[columns]

# %%
GDP
# Out:
#          Country Name          2006          2007          2008          2009  \
# 0               Aruba           NaN           NaN           NaN           NaN
# 1             Andorra  4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09
# 2         Afghanistan  1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10
# 3              Angola  5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10
# 4             Albania  9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10
# ..                ...           ...           ...           ...           ...
# 259       Yemen, Rep.  2.672565e+10  2.761787e+10  2.872656e+10  2.991436e+10
# 260      South Africa  3.402852e+11  3.585261e+11  3.699668e+11  3.642764e+11
# 261  Congo, Dem. Rep.  1.650894e+10  1.754232e+10  1.863448e+10  1.916651e+10
# 262            Zambia  1.440569e+10  1.560892e+10  1.682234e+10  1.837342e+10
# 263          Zimbabwe  1.006276e+10  9.695130e+09  7.982103e+09  8.459783e+09
#
#              2010          2011          2012          2013          2014  \
# 0    2.467704e+09           NaN           NaN           NaN           NaN
# 1    3.346317e+09  3.185605e+09  3.129538e+09  3.127550e+09           NaN
# 2    1.593680e+10  1.691113e+10  1.935220e+10  1.973134e+10  1.999032e+10
# 3    8.247091e+10  8.570262e+10  9.012096e+10  9.626143e+10  1.008863e+11
# 4    1.192695e+10  1.223109e+10  1.240477e+10  1.254247e+10  1.279331e+10
# ..            ...           ...           ...           ...           ...
# 259  3.090675e+10  2.624342e+10  2.689160e+10  2.800914e+10           NaN
# 260  3.753494e+11  3.874074e+11  3.960071e+11  4.047682e+11  4.110369e+11
# 261  2.052329e+10  2.193213e+10  2.350200e+10  2.550050e+10  2.778776e+10
# 262  2.026555e+10  2.140358e+10  2.302438e+10  2.420595e+10  2.542227e+10
# 263  9.422161e+09  1.054391e+10  1.165789e+10  1.218064e+10  1.264939e+10
#
#              2015
# 0             NaN
# 1             NaN
# 2    2.029415e+10
# 3    1.039106e+11
# 4    1.312082e+10
# ..            ...
# 259           NaN
# 260  4.163117e+11
# 261  2.970961e+10
# 262  2.624127e+10
# 263  1.278517e+10
#
# [264 rows x 11 columns]

# %%
ScimEn = pd.read_excel('scimagojr-3.xlsx')
ScimEn_m = ScimEn[:15]
ScimEn
# Out:
#      Rank             Country  Documents  Citable documents  Citations  \
# 0       1               China     127050             126767     597237
# 1       2       United States      96661              94747     792274
# 2       3               Japan      30504              30287     223024
# 3       4      United Kingdom      20944              20357     206091
# 4       5  Russian Federation      18534              18301      34266
# ..    ...                 ...        ...                ...        ...
# 186   187              Guyana          1                  1          0
# 187   188    Christmas Island          1                  1          0
# 188   189             Reunion          1                  1          2
# 189   190         Saint Lucia          1                  1          0
# 190   191          Mauritania          1                  1          1
#
#      Self-citations  Citations per document  H index
# 0            411683                    4.70      138
# 1            265436                    8.20      230
# 2             61554                    7.31      134
# 3             37874                    9.84      139
# 4             12422                    1.85       57
# ..              ...                     ...      ...
# 186               0                    0.00        0
# 187               0                    0.00        0
# 188               1                    2.00        1
# 189               0                    0.00        0
# 190               0                    1.00        1
#
# [191 rows x 8 columns]

# %%
ScimEn
# Out:
#      Rank             Country  Documents  Citable documents  Citations  \
# 0       1               China     127050             126767     597237
# 1       2       United States      96661              94747     792274
# 2       3               Japan      30504              30287     223024
# 3       4      United Kingdom      20944              20357     206091
# 4       5  Russian Federation      18534              18301      34266
# ..    ...                 ...        ...                ...        ...
# 186   187              Guyana          1                  1          0
# 187   188    Christmas Island          1                  1          0
# 188   189             Reunion          1                  1          2
# 189   190         Saint Lucia          1                  1          0
# 190   191          Mauritania          1                  1          1
#
#      Self-citations  Citations per document  H index
# 0            411683                    4.70      138
# 1            265436                    8.20      230
# 2             61554                    7.31      134
# 3             37874                    9.84      139
# 4             12422                    1.85       57
# ..              ...                     ...      ...
# 186               0                    0.00        0
# 187               0                    0.00        0
# 188               1                    2.00        1
# 189               0                    0.00        0
# 190               0                    1.00        1
#
# [191 rows x 8 columns]

# %%
df = pd.merge(ScimEn_m, energy, how = 'inner', left_on = 'Country', right_on='Country')
final_df = pd.merge(df,GDP, how = 'inner', left_on = 'Country', right_on='Country Name')
final_df = final_df.set_index('Country')
columns = ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
ans = final_df[columns]

# %%
ans
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# South Korea           10      11983              11923     114675
# Iran                  13       8896               8819      57470
# Brazil                15       8668               8596      60702
#
#                     Self-citations  Citations per document  H index  \
# Country
# Russian Federation           12422                    1.85       57
# Canada                       40930                   12.01      149
# Germany                      27426                    8.26      126
# India                        37209                    8.58      115
# South Korea                  22595                    9.57      104
# Iran                         19125                    6.46       72
# Brazil                       14396                    7.00       86
#
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# South Korea          1.100700e+10                     221.0     2.279353
# Iran                 9.172000e+09                     119.0     5.707721
# Brazil               1.214900e+10                      59.0    69.648030
#
#                             2006          2007          2008          2009  \
# Country
# Russian Federation  1.385793e+12  1.504071e+12  1.583004e+12  1.459199e+12
# Canada              1.564469e+12  1.596740e+12  1.612713e+12  1.565145e+12
# Germany             3.332891e+12  3.441561e+12  3.478809e+12  3.283340e+12
# India               1.265894e+12  1.374865e+12  1.428361e+12  1.549483e+12
# South Korea         9.410199e+11  9.924316e+11  1.020510e+12  1.027730e+12
# Iran                3.895523e+11  4.250646e+11  4.289909e+11  4.389208e+11
# Brazil              1.845080e+12  1.957118e+12  2.056809e+12  2.054215e+12
#
#                             2010          2011          2012          2013  \
# Country
# Russian Federation  1.524917e+12  1.589943e+12  1.645876e+12  1.666934e+12
# Canada              1.613406e+12  1.664087e+12  1.693133e+12  1.730688e+12
# Germany             3.417298e+12  3.542371e+12  3.556724e+12  3.567317e+12
# India               1.708459e+12  1.821872e+12  1.924235e+12  2.051982e+12
# South Korea         1.094499e+12  1.134796e+12  1.160809e+12  1.194429e+12
# Iran                4.677902e+11  4.853309e+11  4.532569e+11  4.445926e+11
# Brazil              2.208872e+12  2.295245e+12  2.339209e+12  2.409740e+12
#
#                             2014          2015
# Country
# Russian Federation  1.678709e+12  1.616149e+12
# Canada              1.773486e+12  1.792609e+12
# Germany             3.624386e+12  3.685556e+12
# India               2.200617e+12  2.367206e+12
# South Korea         1.234340e+12  1.266580e+12
# Iran                4.639027e+11           NaN
# Brazil              2.412231e+12  2.319423e+12

# %%
def answer_one():
    energy = pd.read_excel('Energy Indicators.xls', skiprows=17,skipfooter= 38)
    energy=energy.iloc[:,2:]
    energy.columns = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    energy[['Energy Supply', 'Energy Supply per Capita', '% Renewable']] =  energy[['Energy Supply', 'Energy Supply per Capita', '% Renewable']].replace('...',np.NaN).apply(pd.to_numeric)
    energy['Energy Supply'] = energy['Energy Supply']*1000000
    energy['Country'] = energy['Country'].replace({'China, Hong Kong Special Administrative Region':'Hong Kong','United Kingdom of Great Britain and Northern Ireland':'United Kingdom','Republic of Korea':'South Korea','United States of America':'United States','Iran (Islamic Republic of)':'Iran'})
    energy['Country'] = energy['Country'].str.replace(" \(.*\)","")

    GDP = pd.read_csv('world_bank.csv',skiprows=4)
    GDP['Country Name'] = GDP['Country Name'].replace('Korea, Rep.','South Korea')
    GDP['Country Name'] = GDP['Country Name'].replace('Iran, Islamic Rep.','Iran')
    GDP['Country Name'] = GDP['Country Name'].replace('Hong Kong SAR, China','Hong Kong')

    columns = ['Country Name','2006','2007','2008','2009','2010','2011','2012','2013','2014','2015']
    GDP = GDP[columns]

    ScimEn = pd.read_excel('scimagojr-3.xlsx')
    ScimEn_m = ScimEn[:15]

    df = pd.merge(ScimEn_m, energy, how = 'inner', left_on = 'Country', right_on='Country')
    final_df = pd.merge(df,GDP, how = 'inner', left_on = 'Country', right_on='Country Name')
    final_df = final_df.set_index('Country')
    columns = ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
    ans = final_df[columns]

    return ans

answer_one()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# South Korea           10      11983              11923     114675
# Iran                  13       8896               8819      57470
# Brazil                15       8668               8596      60702
#
#                     Self-citations  Citations per document  H index  \
# Country
# Russian Federation           12422                    1.85       57
# Canada                       40930                   12.01      149
# Germany                      27426                    8.26      126
# India                        37209                    8.58      115
# South Korea                  22595                    9.57      104
# Iran                         19125                    6.46       72
# Brazil                       14396                    7.00       86
#
#                     Energy Supply  Energy Supply per Capita  % Renewable  \
# Country
# Russian Federation   3.070900e+10                     214.0    17.288680
# Canada               1.043100e+10                     296.0    61.945430
# Germany              1.326100e+10                     165.0    17.901530
# India                3.319500e+10                      26.0    14.969080
# South Korea          1.100700e+10                     221.0     2.279353
# Iran                 9.172000e+09                     119.0     5.707721
# Brazil               1.214900e+10                      59.0    69.648030
#
#                             2006          2007          2008          2009  \
# Country
# Russian Federation  1.385793e+12  1.504071e+12  1.583004e+12  1.459199e+12
# Canada              1.564469e+12  1.596740e+12  1.612713e+12  1.565145e+12
# Germany             3.332891e+12  3.441561e+12  3.478809e+12  3.283340e+12
# India               1.265894e+12  1.374865e+12  1.428361e+12  1.549483e+12
# South Korea         9.410199e+11  9.924316e+11  1.020510e+12  1.027730e+12
# Iran                3.895523e+11  4.250646e+11  4.289909e+11  4.389208e+11
# Brazil              1.845080e+12  1.957118e+12  2.056809e+12  2.054215e+12
#
#                             2010          2011          2012          2013  \
# Country
# Russian Federation  1.524917e+12  1.589943e+12  1.645876e+12  1.666934e+12
# Canada              1.613406e+12  1.664087e+12  1.693133e+12  1.730688e+12
# Germany             3.417298e+12  3.542371e+12  3.556724e+12  3.567317e+12
# India               1.708459e+12  1.821872e+12  1.924235e+12  2.051982e+12
# South Korea         1.094499e+12  1.134796e+12  1.160809e+12  1.194429e+12
# Iran                4.677902e+11  4.853309e+11  4.532569e+11  4.445926e+11
# Brazil              2.208872e+12  2.295245e+12  2.339209e+12  2.409740e+12
#
#                             2014          2015
# Country
# Russian Federation  1.678709e+12  1.616149e+12
# Canada              1.773486e+12  1.792609e+12
# Germany             3.624386e+12  3.685556e+12
# India               2.200617e+12  2.367206e+12
# South Korea         1.234340e+12  1.266580e+12
# Iran                4.639027e+11           NaN
# Brazil              2.412231e+12  2.319423e+12

# %%
len(final_df)
# Out:
# 7
